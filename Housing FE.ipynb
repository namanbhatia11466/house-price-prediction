# %% [markdown]
# # Housing Dataset Feature engineering

# %%
# Loading files and importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.pandas.set_option('display.max_columns', None)

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
## Finding Null values in CATEGORICAL features:
cfeatures = [feature for feature in df if df[feature].isnull().sum()>1 and df[feature].dtypes =='O']
for i in cfeatures:
    print(i, np.round(df[i].isnull().mean(),4))
# Out:
# Alley 0.9377
# MasVnrType 0.0055
# BsmtQual 0.0253
# BsmtCond 0.0253
# BsmtExposure 0.026
# BsmtFinType1 0.0253
# BsmtFinType2 0.026
# FireplaceQu 0.4726
# GarageType 0.0555
# GarageFinish 0.0555
# GarageQual 0.0555
# GarageCond 0.0555
# PoolQC 0.9952
# Fence 0.8075
# MiscFeature 0.963

# %%
#Replace Null values with Missing word to create a new catagory:
def replace_nan(dataset, features):
    data = dataset.copy()
    data[features] = data[features].fillna('Missing')
    return data
dfmissing = replace_nan(df, cfeatures)
dfmissing[cfeatures].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
dfmissing.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# ...

# %%
#Finding how many nan values numerial features have:
nfeatures = [feature for feature in dfmissing if dfmissing[feature].isnull().sum()>1 and dfmissing[feature].dtypes !='O']
for i in nfeatures:
    print(i, np.round(dfmissing[i].isnull().mean(),4))
# Out:
# LotFrontage 0.1774
# MasVnrArea 0.0055
# GarageYrBlt 0.0555

# %%
#Replacing all the numerical column values to 1 if its null else put 0 there:
for i in nfeatures:
    median = dfmissing[i].median()
    dfmissing[i+'nan'] = np.where(dfmissing[i].isnull(),1,0)
    dfmissing[i].fillna(median,inplace=True)
dfmissing[nfeatures].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
dfmissing.head(2)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# ...

# %%
##Changing features with Years in difference of features :
for i in dfmissing:
    if ('YR' in i.upper() or 'YEAR' in i.upper()) and i != 'YrSold':
        dfmissing[i] = dfmissing['YrSold'] - dfmissing[i]

# %%
dfmissing.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ## Numerical Features

# %%
numfeat = [ i for i in dfmissing if dfmissing[i].dtypes !='O']
numfeat
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice',
#  'LotFrontagenan',
#  'MasVnrAreanan',
#  'GarageYrBltnan']

# %%
#Finding only non zero columns:
numfeatval = []
for i in numfeat:
    if dfmissing[i].isin([0]).any() :
        pass
    else:
        if i != 'Id':
            numfeatval.append(i)
numfeatval
# Out:
# ['MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  '1stFlrSF',
#  'GrLivArea',
#  'TotRmsAbvGrd',
#  'MoSold',
#  'YrSold',
#  'SalePrice',
#  'GarageYrBltnan']

# %%
dfmissing[dfmissing['LotFrontage'].isin([0])]
# Out:
# Empty DataFrame
# ...

# %%
for f in numfeatval:
    dfmissing[f].hist(bins = 25)
    plt.xlabel(f)
    plt.ylabel('Count')
    plt.show()

# %%
#As we can see some skewed values, we will do log transformation for only those values and see the resut:
for i in ['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea','SalePrice', 'MSSubClass']:
    dfmissing[i] = np.log(dfmissing[i])

# %%
for f in numfeatval:
    dfmissing[f].hist(bins = 25)
    plt.xlabel(f)
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# Most of the features are in Normal distribution now.

# %% [markdown]
# ## Handeling Rare Catagorical Features
# Removing all the features which are less than 1% of all the observations

# %%
categorical_features=[feature for feature in dfmissing.columns if dfmissing[feature].dtype=='O']

# %%
for i in categorical_features:
    temp = dfmissing.groupby(i)['SalePrice'].count()/len(dfmissing)
    temp_df = temp[temp>0.01].index
    dfmissing[i]=np.where(dfmissing[i].isin(temp_df),dfmissing[i], 'Rare_var')

# %%
dfmissing.head(50)
# Out:
#     Id  MSSubClass  MSZoning  LotFrontage   LotArea Street  Alley LotShape  \
# 0    1    4.094345        RL     4.174387  9.041922   Pave      2      Reg
# 1    2    2.995732        RL     4.382027  9.169518   Pave      2      Reg
# 2    3    4.094345        RL     4.219508  9.328123   Pave      2      IR1
# 3    4    4.248495        RL     4.094345  9.164296   Pave      2      IR1
# 4    5    4.094345        RL     4.430817  9.565214   Pave      2      IR1
# 5    6    3.912023        RL     4.442651  9.554993   Pave      2      IR1
# 6    7    2.995732        RL     4.317488  9.218705   Pave      2      Reg
# 7    8    4.094345        RL     4.234107  9.247829   Pave      2      IR1
# 8    9    3.912023        RM     3.931826  8.719317   Pave      2      Reg
# 9   10    5.247024        RL     3.912023  8.911934   Pave      2      Reg
# 10  11    2.995732        RL     4.248495  9.323669   Pave      2      Reg
# ...

# %% [markdown]
# # Changing categorical features in terms of numbers

# %%
for feature in categorical_features:
    labels_ordered=dfmissing.groupby([feature])['SalePrice'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    dfmissing[feature]=dfmissing[feature].map(labels_ordered)

# %%
dfmissing.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0   1    4.094345         3     4.174387  9.041922       1      2         0
# 1   2    2.995732         3     4.382027  9.169518       1      2         0
# 2   3    4.094345         3     4.219508  9.328123       1      2         1
# 3   4    4.248495         3     4.094345  9.164296       1      2         1
# 4   5    4.094345         3     4.430817  9.565214       1      2         1
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            1          1          0          0            14           2
# 1            1          1          2          0            11           1
# 2            1          1          0          0            14           2
# 3            1          1          1          0            16           2
# 4            1          1          2          0            22           2
#
# ...

# %% [markdown]
# # Feature Scaling

# %%
feature_scale = [feature for feature in dfmissing.columns if feature not in ['Id','SalePrice']]

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(dfmissing[feature_scale])
# Out:
# MinMaxScaler()

# %%
dfmissing.head(20)
# Out:
#     Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0    1    4.094345         3     4.174387  9.041922       1      2         0
# 1    2    2.995732         3     4.382027  9.169518       1      2         0
# 2    3    4.094345         3     4.219508  9.328123       1      2         1
# 3    4    4.248495         3     4.094345  9.164296       1      2         1
# 4    5    4.094345         3     4.430817  9.565214       1      2         1
# 5    6    3.912023         3     4.442651  9.554993       1      2         1
# 6    7    2.995732         3     4.317488  9.218705       1      2         0
# 7    8    4.094345         3     4.234107  9.247829       1      2         1
# 8    9    3.912023         1     3.931826  8.719317       1      2         0
# 9   10    5.247024         3     3.912023  8.911934       1      2         0
# 10  11    2.995732         3     4.248495  9.323669       1      2         0
# ...

# %%
data = pd.concat([dfmissing[['Id','SalePrice']].reset_index(drop=True), 
                 pd.DataFrame(scaler.transform(dfmissing[feature_scale]), columns=feature_scale)],axis=1)

# %%
data.head()
# Out:
#    Id  SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0   1  12.247694    0.487992      0.75     0.418208  0.366344     1.0    1.0
# 1   2  12.109011    0.000000      0.75     0.495064  0.391317     1.0    1.0
# 2   3  12.317167    0.487992      0.75     0.434909  0.422359     1.0    1.0
# 3   4  11.849398    0.556464      0.75     0.388581  0.390295     1.0    1.0
# 4   5  12.429216    0.487992      0.75     0.513123  0.468761     1.0    1.0
#
#    LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 0  0.000000     0.333333        1.0       0.00        0.0      0.636364
# 1  0.000000     0.333333        1.0       0.50        0.0      0.500000
# 2  0.333333     0.333333        1.0       0.00        0.0      0.636364
# 3  0.333333     0.333333        1.0       0.25        0.0      0.727273
# 4  0.333333     0.333333        1.0       0.50        0.0      1.000000
#
# ...

# %%
data.to_csv('X_train.csv', index=False)
